# %%
import pandas as pd
import numpy as np
import os 
from os import listdir
import cv2
import glob
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import random

# %%
# !ls "/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented/"
# Out:
# Damaged_Infrastructure	Human_Damage   Non_Damage
# Fire_Disaster		Land_Disaster  Water_Disaster

# %%
DI_img_path="/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented/Damaged_Infrastructure"
FD_img_path="/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented/Human_Damage"
HD_img_path="/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented/Non_Damage"
LD_img_path="/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented/Fire_Disaster"
ND_img_path="/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented/Land_Disaster"
WD_img_path="/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented/Water_Disaster"

# %%
file_path_type=["/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented/Damaged_Infrastructure/*.jpg"]

# %%
img=mpimg.imread("/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented/Damaged_Infrastructure/16916.jpg")
plt.imshow(img)
plt.show()

# %%
for foldername in listdir("/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented"):
    for filename in listdir("/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented/" + foldername):
        try:
            with Image.open("/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented/" + foldername + "/" + filename) as img:
                img.verify()
        except (IOError, SyntaxError):
            print(filename)

# %%
#images=glob.glob("/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented/Damaged_Infrastructure/*.jpg")
#images=glob.glob("/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented/Human_Damage/*.jpg")
images=glob.glob("/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented/Non_Damage/*.jpg")
#images=glob.glob("/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented/Fire_Disaster/*.jpg")
#images=glob.glob("/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented/Land_Disaster/*.jpg")
#images=glob.glob("/kaggle/input/datasets/anonymous62827/disaster/Comprehensive Disaster Dataset(CDD)/CDD_Augmented/Water_Disaster/*.jpg")

for i in range(0,10): 
    random_image = random.choice(images)
    img=mpimg.imread(random_image)
    plt.imshow(img)
    plt.show()

# %%
height, width, channels = img.shape
print(f"Image Height:", height)
print(f"Image Width:", width)
print(f"Image Channels:", channels)
print(f"Image Shape: {height} x {width} x {channels}")
# Out:
# Image Height: 600
# Image Width: 600
# Image Channels: 3
# Image Shape: 600 x 600 x 3

# %%
plt.figure(figsize = (20, 5))
plt.hist(img.flatten(), bins=256, range=(0, 256), density=True, color='blue', alpha=0.7)
plt.title('Pixel Intensity Distribution')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')
plt.show()
